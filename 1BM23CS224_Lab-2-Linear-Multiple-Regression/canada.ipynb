# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("canada_per_capita_income.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 884.0 bytes

# %%
plt.scatter(df["year"] ,df["per capita income (US$)"])

# %%
X = df[["year"]]
y = df["per capita income (US$)"]

X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size = 0.2)

model = LinearRegression()
model.fit(X_train,Y_train)

print(model.coef_)
print(model.intercept_)
# Out:
# [838.86701137]
# -1653037.2787202643

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test,y_pred)
# Out:
# 3781448.506465943

# %%
prediction_2020 = model.predict([[2020]])
print("Predicted income for 2020:", prediction_2020[0])
# Out:
# Predicted income for 2020: 41474.08425306645
# C:\Users\BMSCECSE-SH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
